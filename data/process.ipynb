# %%
import pandas as pd

# %%
df = pd.read_excel("./BerkDataRAW.xlsx")
df
# Out:
#                FacultyName  FacultyCode  DepartmentCode  \
# 0    Mühendislik Fakültesi            8            1040
# 1    Mühendislik Fakültesi            8            1040
# 2    Mühendislik Fakültesi            8            1040
# 3    Mühendislik Fakültesi            8              35
# 4    Mühendislik Fakültesi            8              38
# ..                     ...          ...             ...
# 504  Mühendislik Fakültesi            8              38
# 505  Mühendislik Fakültesi            8              35
# 506  Mühendislik Fakültesi            8              35
# 507  Mühendislik Fakültesi            8              38
# 508  Mühendislik Fakültesi            8              35
#
#                            DepartmentName CourseCode  \
# 0    Bilgisayar Mühendisliği  (İngilizce)    CSE 214
# 1    Bilgisayar Mühendisliği  (İngilizce)    CSE 214
# 2    Bilgisayar Mühendisliği  (İngilizce)    CSE 336
# 3                     İnşaat Mühendisliği    İNM 206
# 4                    Jeoloji Mühendisliği    JEO 202
# ..                                    ...        ...
# 504                  Jeoloji Mühendisliği    JEO 408
# 505                   İnşaat Mühendisliği    İNM 476
# 506                   İnşaat Mühendisliği    JEO 308
# 507                  Jeoloji Mühendisliği    JEO 308
# 508                   İnşaat Mühendisliği    İNM 360
#
#                            CourseName  CourseId EducationType  \
# 0    Advanced Application Development   6287177  Örgün Eğitim
# 1    Advanced Application Development   6287180  Örgün Eğitim
# 2            Advanced Web Programming   6287191  Örgün Eğitim
# 3                 Akışkanlar Mekaniği   6285587  Örgün Eğitim
# 4                 Akışkanlar Mekaniği   6269432  Örgün Eğitim
# ..                                ...       ...           ...
# 504                 Yeraltı Jeolojisi   6269457  Örgün Eğitim
# 505                    Yüksek Yapılar   6287142  Örgün Eğitim
# 506                    Zemin Mekaniği   6269440  Örgün Eğitim
# 507                    Zemin Mekaniği   6269440  Örgün Eğitim
# 508                  Zemin Mekaniği 2   6287105  Örgün Eğitim
#
#      CourseSectionCode  AKTS  DERS_ID DONEM_TIP  KREDI  LAB_SAAT  SINIF  \
# 0                    1     6  6287177     Bahar      4         0      2
# 1                    2     6  6287180     Bahar      4         0      2
# 2                    1     6  6287191     Bahar      4         0      3
# 3                    1     4  6285587     Bahar      3         0      2
# 4                    1     5  6269432     Bahar      3         0      2
# ..                 ...   ...      ...       ...    ...       ...    ...
# 504                  1     5  6269457     Bahar      3         0      4
# 505                  1     5  6287142     Bahar      3         0      4
# 506                  1     5  6269440     Bahar      4         0      3
# 507                  1     5  6269440     Bahar      4         0      3
# 508                  1     5  6287105     Bahar      3         0      3
#
#      TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi
# 0           3         2       Z           3435711             26
# 1           3         2       Z           3435711             40
# 2           3         1       S           2107934             12
# 3           2         1       Z           3048102            125
# 4           2         1       Z           1098471              7
# ..        ...       ...     ...               ...            ...
# 504         2         1       Z           5997408              9
# 505         2         1       S           3524624             15
# 506         3         1       Z           1892200              2
# 507         3         1       Z           1892200              5
# 508         2         1       S           2977082             52
#
# [509 rows x 20 columns]

# %%
df.drop(index=df[df['KREDI'] == 0].index, inplace=True)
df
# Out:
#                FacultyName  FacultyCode  DepartmentCode  \
# 0    Mühendislik Fakültesi            8            1040
# 1    Mühendislik Fakültesi            8            1040
# 2    Mühendislik Fakültesi            8            1040
# 3    Mühendislik Fakültesi            8              35
# 4    Mühendislik Fakültesi            8              38
# ..                     ...          ...             ...
# 504  Mühendislik Fakültesi            8              38
# 505  Mühendislik Fakültesi            8              35
# 506  Mühendislik Fakültesi            8              35
# 507  Mühendislik Fakültesi            8              38
# 508  Mühendislik Fakültesi            8              35
#
#                            DepartmentName CourseCode  \
# 0    Bilgisayar Mühendisliği  (İngilizce)    CSE 214
# 1    Bilgisayar Mühendisliği  (İngilizce)    CSE 214
# 2    Bilgisayar Mühendisliği  (İngilizce)    CSE 336
# 3                     İnşaat Mühendisliği    İNM 206
# 4                    Jeoloji Mühendisliği    JEO 202
# ..                                    ...        ...
# 504                  Jeoloji Mühendisliği    JEO 408
# 505                   İnşaat Mühendisliği    İNM 476
# 506                   İnşaat Mühendisliği    JEO 308
# 507                  Jeoloji Mühendisliği    JEO 308
# 508                   İnşaat Mühendisliği    İNM 360
#
#                            CourseName  CourseId EducationType  \
# 0    Advanced Application Development   6287177  Örgün Eğitim
# 1    Advanced Application Development   6287180  Örgün Eğitim
# 2            Advanced Web Programming   6287191  Örgün Eğitim
# 3                 Akışkanlar Mekaniği   6285587  Örgün Eğitim
# 4                 Akışkanlar Mekaniği   6269432  Örgün Eğitim
# ..                                ...       ...           ...
# 504                 Yeraltı Jeolojisi   6269457  Örgün Eğitim
# 505                    Yüksek Yapılar   6287142  Örgün Eğitim
# 506                    Zemin Mekaniği   6269440  Örgün Eğitim
# 507                    Zemin Mekaniği   6269440  Örgün Eğitim
# 508                  Zemin Mekaniği 2   6287105  Örgün Eğitim
#
#      CourseSectionCode  AKTS  DERS_ID DONEM_TIP  KREDI  LAB_SAAT  SINIF  \
# 0                    1     6  6287177     Bahar      4         0      2
# 1                    2     6  6287180     Bahar      4         0      2
# 2                    1     6  6287191     Bahar      4         0      3
# 3                    1     4  6285587     Bahar      3         0      2
# 4                    1     5  6269432     Bahar      3         0      2
# ..                 ...   ...      ...       ...    ...       ...    ...
# 504                  1     5  6269457     Bahar      3         0      4
# 505                  1     5  6287142     Bahar      3         0      4
# 506                  1     5  6269440     Bahar      4         0      3
# 507                  1     5  6269440     Bahar      4         0      3
# 508                  1     5  6287105     Bahar      3         0      3
#
#      TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi
# 0           3         2       Z           3435711             26
# 1           3         2       Z           3435711             40
# 2           3         1       S           2107934             12
# 3           2         1       Z           3048102            125
# 4           2         1       Z           1098471              7
# ..        ...       ...     ...               ...            ...
# 504         2         1       Z           5997408              9
# 505         2         1       S           3524624             15
# 506         3         1       Z           1892200              2
# 507         3         1       Z           1892200              5
# 508         2         1       S           2977082             52
#
# [495 rows x 20 columns]

# %%
drop_cols = ['FacultyName', 'FacultyCode', 'DepartmentCode', 'CourseId', 'AKTS', 'DERS_ID', 'DONEM_TIP']
df.drop(labels=drop_cols, inplace=True, axis=1)
df
# Out:
#                            DepartmentName CourseCode  \
# 0    Bilgisayar Mühendisliği  (İngilizce)    CSE 214
# 1    Bilgisayar Mühendisliği  (İngilizce)    CSE 214
# 2    Bilgisayar Mühendisliği  (İngilizce)    CSE 336
# 3                     İnşaat Mühendisliği    İNM 206
# 4                    Jeoloji Mühendisliği    JEO 202
# ..                                    ...        ...
# 504                  Jeoloji Mühendisliği    JEO 408
# 505                   İnşaat Mühendisliği    İNM 476
# 506                   İnşaat Mühendisliği    JEO 308
# 507                  Jeoloji Mühendisliği    JEO 308
# 508                   İnşaat Mühendisliği    İNM 360
#
#                            CourseName EducationType  CourseSectionCode  KREDI  \
# 0    Advanced Application Development  Örgün Eğitim                  1      4
# 1    Advanced Application Development  Örgün Eğitim                  2      4
# 2            Advanced Web Programming  Örgün Eğitim                  1      4
# 3                 Akışkanlar Mekaniği  Örgün Eğitim                  1      3
# 4                 Akışkanlar Mekaniği  Örgün Eğitim                  1      3
# ..                                ...           ...                ...    ...
# 504                 Yeraltı Jeolojisi  Örgün Eğitim                  1      3
# 505                    Yüksek Yapılar  Örgün Eğitim                  1      3
# 506                    Zemin Mekaniği  Örgün Eğitim                  1      4
# 507                    Zemin Mekaniği  Örgün Eğitim                  1      4
# 508                  Zemin Mekaniği 2  Örgün Eğitim                  1      3
#
#      LAB_SAAT  SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  \
# 0           0      2         3         2       Z           3435711
# 1           0      2         3         2       Z           3435711
# 2           0      3         3         1       S           2107934
# 3           0      2         2         1       Z           3048102
# 4           0      2         2         1       Z           1098471
# ..        ...    ...       ...       ...     ...               ...
# 504         0      4         2         1       Z           5997408
# 505         0      4         2         1       S           3524624
# 506         0      3         3         1       Z           1892200
# 507         0      3         3         1       Z           1892200
# 508         0      3         2         1       S           2977082
#
#      OgrenciSayisi
# 0               26
# 1               40
# 2               12
# 3              125
# 4                7
# ..             ...
# 504              9
# 505             15
# 506              2
# 507              5
# 508             52
#
# [495 rows x 13 columns]

# %%
df["DepartmentName"] = (
    df["DepartmentName"]
    .str.replace(r'\s*\(.*?\)', '', regex=True)
    .str.strip()                                
)

deps = df["DepartmentName"].unique()
deps
# Out:
# array(['Bilgisayar Mühendisliği', 'İnşaat Mühendisliği',
#        'Jeoloji Mühendisliği', 'Gıda Mühendisliği',
#        'Elektrik-Elektronik Mühendisliği', 'Makine Mühendisliği',
#        'Çevre Mühendisliği', 'Yapay Zeka ve Veri Mühendisliği'],
#       dtype=object)

# %%
for dep in deps:
    codes = df[df["DepartmentName"] == dep]["CourseCode"].unique()
    for code in codes:
        # Filter the rows with the same DepartmentName and CourseCode
        courses = df[(df["DepartmentName"] == dep) & (df["CourseCode"] == code)]
        if len(courses) > 1:
            sum_count = courses["OgrenciSayisi"].sum()
            
            # Keep the first index, drop the rest
            keep_index = courses.index[0]
            drop_indices = courses.index[1:]
            
            df.loc[keep_index, "OgrenciSayisi"] = sum_count
            df.drop(drop_indices, inplace=True)

# Reset index if necessary
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#               DepartmentName CourseCode                        CourseName  \
# 0    Bilgisayar Mühendisliği    CSE 214  Advanced Application Development
# 1    Bilgisayar Mühendisliği    CSE 336          Advanced Web Programming
# 2        İnşaat Mühendisliği    İNM 206               Akışkanlar Mekaniği
# 3       Jeoloji Mühendisliği    JEO 202               Akışkanlar Mekaniği
# 4          Gıda Mühendisliği   GIDA 224               Akışkanlar Mekaniği
# ..                       ...        ...                               ...
# 288     Jeoloji Mühendisliği    JEO 408                 Yeraltı Jeolojisi
# 289      İnşaat Mühendisliği    İNM 476                    Yüksek Yapılar
# 290      İnşaat Mühendisliği    JEO 308                    Zemin Mekaniği
# 291     Jeoloji Mühendisliği    JEO 308                    Zemin Mekaniği
# 292      İnşaat Mühendisliği    İNM 360                  Zemin Mekaniği 2
#
#     EducationType  CourseSectionCode  KREDI  LAB_SAAT  SINIF  TEO_SAAT  \
# 0    Örgün Eğitim                  1      4         0      2         3
# 1    Örgün Eğitim                  1      4         0      3         3
# 2    Örgün Eğitim                  1      3         0      2         2
# 3    Örgün Eğitim                  1      3         0      2         2
# 4    Örgün Eğitim                  1      3         0      2         3
# ..            ...                ...    ...       ...    ...       ...
# 288  Örgün Eğitim                  1      3         0      4         2
# 289  Örgün Eğitim                  1      3         0      4         2
# 290  Örgün Eğitim                  1      4         0      3         3
# 291  Örgün Eğitim                  1      4         0      3         3
# 292  Örgün Eğitim                  1      3         0      3         2
#
#      UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi
# 0           2       Z           3435711             66
# 1           1       S           2107934             12
# 2           1       Z           3048102            125
# 3           1       Z           1098471              7
# 4           0       Z           2061533             72
# ..        ...     ...               ...            ...
# 288         1       Z           5997408              9
# 289         1       S           3524624             15
# 290         1       Z           1892200              2
# 291         1       Z           1892200              5
# 292         1       S           2977082             52
#
# [293 rows x 13 columns]

# %%
df.to_excel("./BerkData3RAW.xlsx", index=False, header=True)

# %% [markdown]
# Lab saatlerini uygulamaya yaz
