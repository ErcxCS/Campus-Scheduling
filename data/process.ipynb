# %%
import pandas as pd

# %%
df = pd.read_excel("./25-26Fall.xlsx")
df
# Out:
#                FacultyName  FacultyCode  DepartmentCode  \
# 0    Mühendislik Fakültesi            8              36
# 1    Mühendislik Fakültesi            8              36
# 2    Mühendislik Fakültesi            8              37
# 3    Mühendislik Fakültesi            8              36
# 4    Mühendislik Fakültesi            8              37
# ..                     ...          ...             ...
# 528  Mühendislik Fakültesi            8              38
# 529  Mühendislik Fakültesi            8              37
# 530  Mühendislik Fakültesi            8              39
# 531  Mühendislik Fakültesi            8             808
# 532  Mühendislik Fakültesi            8              35
#
#                             DepartmentName CourseCode  \
# 0                       Çevre Mühendisliği    ÇEV 457
# 1                       Çevre Mühendisliği    ÇEV 461
# 2                      Makine Mühendisliği    TDB 115
# 3                       Çevre Mühendisliği    ÇEV 207
# 4                      Makine Mühendisliği    MAK 307
# ..                                     ...        ...
# 528                   Jeoloji Mühendisliği    JEO 209
# 529                    Makine Mühendisliği    MAK 471
# 530       Elektrik-Elektronik Mühendisliği    EEE 499
# 531  Elektrik-Elektronik Mühendisliği (İÖ)    EEE 499
# 532                    İnşaat Mühendisliği    İNM 301
#
#                           CourseName  CourseId EducationType  \
# 0              Air Pollution Control   6317538  Örgün Eğitim
# 1            Air Pollution Modelling   6317540  Örgün Eğitim
# 2                    Akademik Türkçe   6317698  Örgün Eğitim
# 3                Akışkanlar Mekaniği   6317652  Örgün Eğitim
# 4                Akışkanlar Mekaniği   6357316  Örgün Eğitim
# ..                               ...       ...           ...
# 528                  Yapısal Jeoloji   6322615  Örgün Eğitim
# 529  Yenilenebilir Enerji Kaynakları   6323242  Örgün Eğitim
# 530  Yenilenebilir Enerji Kaynakları   6346720  Örgün Eğitim
# 531  Yenilenebilir Enerji Kaynakları   6346758     2.Öğretim
# 532                 Zemin Mekaniği 1   6324548  Örgün Eğitim
#
#      CourseSectionCode  AKTS  DERS_ID            DONEM_TIP  KREDI  LAB_SAAT  \
# 0                    1     5  6317538                  Güz      3         0
# 1                    1     5  6317540                  Güz      3         1
# 2                    1     5  6317698                  Güz      3         0
# 3                    1     3  6317652                  Güz      3         0
# 4                    1     6  6357316  Güz Öncesi Tek Ders      4         0
# ..                 ...   ...      ...                  ...    ...       ...
# 528                  1     5  6322615                  Güz      4         0
# 529                  1     3  6323242                  Güz      2         0
# 530                  1     5  6346720                  Güz      3         0
# 531                  1     5  6346758                  Güz      3         0
# 532                  1     5  6324548                  Güz      4         0
#
#      SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi
# 0        4         2         1       S           4205238              6
# 1        4         2         0       S           4419464              9
# 2        1         3         0       S           2615883              1
# 3        2         2         1       S           1666337             15
# 4        3         4         0       Z           2576518              1
# ..     ...       ...       ...     ...               ...            ...
# 528      2         3         1       Z           2446060             13
# 529      4         2         0       S           2832797             14
# 530      4         3         0       S           3473810             39
# 531      4         3         0       S           3473810             42
# 532      3         3         1       Z           2977082            125
#
# [533 rows x 20 columns]

# %%
df.drop(index=df[df['KREDI'] == 0].index, inplace=True)
df
# Out:
#                FacultyName  FacultyCode  DepartmentCode  \
# 0    Mühendislik Fakültesi            8              36
# 1    Mühendislik Fakültesi            8              36
# 2    Mühendislik Fakültesi            8              37
# 3    Mühendislik Fakültesi            8              36
# 4    Mühendislik Fakültesi            8              37
# ..                     ...          ...             ...
# 528  Mühendislik Fakültesi            8              38
# 529  Mühendislik Fakültesi            8              37
# 530  Mühendislik Fakültesi            8              39
# 531  Mühendislik Fakültesi            8             808
# 532  Mühendislik Fakültesi            8              35
#
#                             DepartmentName CourseCode  \
# 0                       Çevre Mühendisliği    ÇEV 457
# 1                       Çevre Mühendisliği    ÇEV 461
# 2                      Makine Mühendisliği    TDB 115
# 3                       Çevre Mühendisliği    ÇEV 207
# 4                      Makine Mühendisliği    MAK 307
# ..                                     ...        ...
# 528                   Jeoloji Mühendisliği    JEO 209
# 529                    Makine Mühendisliği    MAK 471
# 530       Elektrik-Elektronik Mühendisliği    EEE 499
# 531  Elektrik-Elektronik Mühendisliği (İÖ)    EEE 499
# 532                    İnşaat Mühendisliği    İNM 301
#
#                           CourseName  CourseId EducationType  \
# 0              Air Pollution Control   6317538  Örgün Eğitim
# 1            Air Pollution Modelling   6317540  Örgün Eğitim
# 2                    Akademik Türkçe   6317698  Örgün Eğitim
# 3                Akışkanlar Mekaniği   6317652  Örgün Eğitim
# 4                Akışkanlar Mekaniği   6357316  Örgün Eğitim
# ..                               ...       ...           ...
# 528                  Yapısal Jeoloji   6322615  Örgün Eğitim
# 529  Yenilenebilir Enerji Kaynakları   6323242  Örgün Eğitim
# 530  Yenilenebilir Enerji Kaynakları   6346720  Örgün Eğitim
# 531  Yenilenebilir Enerji Kaynakları   6346758     2.Öğretim
# 532                 Zemin Mekaniği 1   6324548  Örgün Eğitim
#
#      CourseSectionCode  AKTS  DERS_ID            DONEM_TIP  KREDI  LAB_SAAT  \
# 0                    1     5  6317538                  Güz      3         0
# 1                    1     5  6317540                  Güz      3         1
# 2                    1     5  6317698                  Güz      3         0
# 3                    1     3  6317652                  Güz      3         0
# 4                    1     6  6357316  Güz Öncesi Tek Ders      4         0
# ..                 ...   ...      ...                  ...    ...       ...
# 528                  1     5  6322615                  Güz      4         0
# 529                  1     3  6323242                  Güz      2         0
# 530                  1     5  6346720                  Güz      3         0
# 531                  1     5  6346758                  Güz      3         0
# 532                  1     5  6324548                  Güz      4         0
#
#      SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi
# 0        4         2         1       S           4205238              6
# 1        4         2         0       S           4419464              9
# 2        1         3         0       S           2615883              1
# 3        2         2         1       S           1666337             15
# 4        3         4         0       Z           2576518              1
# ..     ...       ...       ...     ...               ...            ...
# 528      2         3         1       Z           2446060             13
# 529      4         2         0       S           2832797             14
# 530      4         3         0       S           3473810             39
# 531      4         3         0       S           3473810             42
# 532      3         3         1       Z           2977082            125
#
# [518 rows x 20 columns]

# %%
allowed = ["KPD 102", "FİZ 176", "CSE 102L", "CSE 392"]

df.drop(
    index=df[
        (df['KREDI'] == 1) & (~df['CourseCode'].isin(allowed))
    ].index,
    inplace=True
)

# %%
drop_cols = ['FacultyName', 'FacultyCode', 'DepartmentCode', 'CourseId', 'AKTS', 'DERS_ID', 'DONEM_TIP']
df.drop(labels=drop_cols, inplace=True, axis=1)
df
# Out:
#                             DepartmentName CourseCode  \
# 0                       Çevre Mühendisliği    ÇEV 457
# 1                       Çevre Mühendisliği    ÇEV 461
# 2                      Makine Mühendisliği    TDB 115
# 3                       Çevre Mühendisliği    ÇEV 207
# 4                      Makine Mühendisliği    MAK 307
# ..                                     ...        ...
# 528                   Jeoloji Mühendisliği    JEO 209
# 529                    Makine Mühendisliği    MAK 471
# 530       Elektrik-Elektronik Mühendisliği    EEE 499
# 531  Elektrik-Elektronik Mühendisliği (İÖ)    EEE 499
# 532                    İnşaat Mühendisliği    İNM 301
#
#                           CourseName EducationType  CourseSectionCode  KREDI  \
# 0              Air Pollution Control  Örgün Eğitim                  1      3
# 1            Air Pollution Modelling  Örgün Eğitim                  1      3
# 2                    Akademik Türkçe  Örgün Eğitim                  1      3
# 3                Akışkanlar Mekaniği  Örgün Eğitim                  1      3
# 4                Akışkanlar Mekaniği  Örgün Eğitim                  1      4
# ..                               ...           ...                ...    ...
# 528                  Yapısal Jeoloji  Örgün Eğitim                  1      4
# 529  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      2
# 530  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      3
# 531  Yenilenebilir Enerji Kaynakları     2.Öğretim                  1      3
# 532                 Zemin Mekaniği 1  Örgün Eğitim                  1      4
#
#      LAB_SAAT  SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  \
# 0           0      4         2         1       S           4205238
# 1           1      4         2         0       S           4419464
# 2           0      1         3         0       S           2615883
# 3           0      2         2         1       S           1666337
# 4           0      3         4         0       Z           2576518
# ..        ...    ...       ...       ...     ...               ...
# 528         0      2         3         1       Z           2446060
# 529         0      4         2         0       S           2832797
# 530         0      4         3         0       S           3473810
# 531         0      4         3         0       S           3473810
# 532         0      3         3         1       Z           2977082
#
#      OgrenciSayisi
# 0                6
# 1                9
# 2                1
# 3               15
# 4                1
# ..             ...
# 528             13
# 529             14
# 530             39
# 531             42
# 532            125
#
# [446 rows x 13 columns]

# %%
df["DepartmentName"] = (
    df["DepartmentName"]
    .str.replace(r'\s*\(.*?\)', '', regex=True)
    .str.strip()                                
)

deps = df["DepartmentName"].unique()
deps
# Out:
# array(['Çevre Mühendisliği', 'Makine Mühendisliği',
#        'Bilgisayar Mühendisliği', 'Gıda Mühendisliği',
#        'Jeoloji Mühendisliği', 'Elektrik-Elektronik Mühendisliği',
#        'Yapay Zeka ve Veri Mühendisliği', 'İnşaat Mühendisliği'],
#       dtype=object)

# %%
df["DepartmentName"] = df["DepartmentName"].replace(
    {"Yapay Zeka ve Veri Mühendisliği": "Bilgisayar Mühendisliği"}
)

# %%
remove_codes = ["ATA 102", "TDB 102", "TDP 100", "TDP 304", "YBD 102", "YBD 104"]
df.drop(
    index=df[
        #df["CourseCode"].isin(remove_codes) |
        df["CourseCode"].str.contains("HOBİ", na=False) |
        df["CourseCode"].str.contains("ATA", na=False) |
        df["CourseCode"].str.contains("TDB", na=False) |
        df["CourseCode"].str.contains("TDP", na=False) |
        df["CourseCode"].str.contains("YBD", na=False) |
        df["CourseCode"].str.contains("PFE", na=False)
    ].index,
    inplace=True
)

# %%
for dep in deps:
    codes = df[df["DepartmentName"] == dep]["CourseCode"].unique()
    for code in codes:
        # Filter the rows with the same DepartmentName and CourseCode
        courses = df[(df["DepartmentName"] == dep) & (df["CourseCode"] == code)]
        if len(courses) > 1:
            sum_count = courses["OgrenciSayisi"].sum()
            
            # Keep the first index, drop the rest
            keep_index = courses.index[0]
            drop_indices = courses.index[1:]
            
            df.loc[keep_index, "OgrenciSayisi"] = sum_count
            df.drop(drop_indices, inplace=True)

# Reset index if necessary
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                        DepartmentName CourseCode  \
# 0                  Çevre Mühendisliği    ÇEV 457
# 1                  Çevre Mühendisliği    ÇEV 461
# 2                  Çevre Mühendisliği    ÇEV 207
# 3                 Makine Mühendisliği    MAK 307
# 4             Bilgisayar Mühendisliği    CSE 301
# ..                                ...        ...
# 234               İnşaat Mühendisliği    İNM 467
# 235              Jeoloji Mühendisliği    JEO 209
# 236               Makine Mühendisliği    MAK 471
# 237  Elektrik-Elektronik Mühendisliği    EEE 499
# 238               İnşaat Mühendisliği    İNM 301
#
#                           CourseName EducationType  CourseSectionCode  KREDI  \
# 0              Air Pollution Control  Örgün Eğitim                  1      3
# 1            Air Pollution Modelling  Örgün Eğitim                  1      3
# 2                Akışkanlar Mekaniği  Örgün Eğitim                  1      3
# 3                Akışkanlar Mekaniği  Örgün Eğitim                  1      4
# 4                         Algorithms  Örgün Eğitim                  1      5
# ..                               ...           ...                ...    ...
# 234  Yapıların Yalıtımı ve Korunması  Örgün Eğitim                  1      3
# 235                  Yapısal Jeoloji  Örgün Eğitim                  1      4
# 236  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      2
# 237  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      3
# 238                 Zemin Mekaniği 1  Örgün Eğitim                  1      4
#
#      LAB_SAAT  SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  \
# 0           0      4         2         1       S           4205238
# 1           1      4         2         0       S           4419464
# 2           0      2         2         1       S           1666337
# 3           0      3         4         0       Z           2576518
# 4           0      3         4         1       Z           7248701
# ..        ...    ...       ...       ...     ...               ...
# 234         0      4         2         1       S           1021641
# 235         0      2         3         1       Z           2446060
# 236         0      4         2         0       S           2832797
# 237         0      4         3         0       S           3473810
# 238         0      3         3         1       Z           2977082
#
#      OgrenciSayisi
# 0                6
# 1                9
# 2               15
# 3              105
# 4              116
# ..             ...
# 234             23
# 235             13
# 236             14
# 237             81
# 238            125
#
# [239 rows x 13 columns]

# %%
df2 = pd.read_excel("./course_data.xlsx")
df2
# Out:
#               DepartmentName CourseCode  \
# 0         Çevre Mühendisliği    ÇEV 102
# 1         Çevre Mühendisliği    ÇEV 108
# 2         Çevre Mühendisliği    ÇEV 156
# 3         Çevre Mühendisliği    ÇEV 160
# 4         Çevre Mühendisliği    ÇEV 162
# ..                       ...        ...
# 221     Jeoloji Mühendisliği    MAT 162
# 222        Gıda Mühendisliği    MAT 162
# 223      Makine Mühendisliği    MAT 162
# 224  Bilgisayar Mühendisliği    MAT 222
# 225      Makine Mühendisliği    MTH 404
#
#                                   CourseName  SINIF ZOR_SEC  InstructorUserId  \
# 0                            Çevre Ekolojisi      1       Z           3979315
# 1                        Statik ve Mukavemet      1       S           1098471
# 2                       Computer Programming      1       Z           1307360
# 3                       Analytical Chemistry      1       S           2719999
# 4                                 Physics II      1       S           1830239
# ..                                       ...    ...     ...               ...
# 221                              Matematik 2      1       Z           2550816
# 222                             Matematik II      1       Z           4117613
# 223                             Matematik II      1       Z           1739868
# 224                           Linear Algebra      2       Z           4693090
# 225  Havacılık Yapısalları İmalat Teknikleri      4       S           1210302
#
#      OgrenciSayisi  Lab
# 0               19    0
# 1               19    0
# 2               18    1
# 3               22    0
# 4               18    0
# ..             ...  ...
# 221             15    0
# 222             99    0
# 223            159    0
# 224            135    0
# 225             34    0
#
# [226 rows x 8 columns]

# %%
diff = df[~df['CourseCode'].isin(df2['CourseCode'])]
diff
# Out:
#                        DepartmentName CourseCode  \
# 0                  Çevre Mühendisliği    ÇEV 457
# 1                  Çevre Mühendisliği    ÇEV 461
# 2                  Çevre Mühendisliği    ÇEV 207
# 3                 Makine Mühendisliği    MAK 307
# 4             Bilgisayar Mühendisliği    CSE 301
# ..                                ...        ...
# 234               İnşaat Mühendisliği    İNM 467
# 235              Jeoloji Mühendisliği    JEO 209
# 236               Makine Mühendisliği    MAK 471
# 237  Elektrik-Elektronik Mühendisliği    EEE 499
# 238               İnşaat Mühendisliği    İNM 301
#
#                           CourseName EducationType  CourseSectionCode  KREDI  \
# 0              Air Pollution Control  Örgün Eğitim                  1      3
# 1            Air Pollution Modelling  Örgün Eğitim                  1      3
# 2                Akışkanlar Mekaniği  Örgün Eğitim                  1      3
# 3                Akışkanlar Mekaniği  Örgün Eğitim                  1      4
# 4                         Algorithms  Örgün Eğitim                  1      5
# ..                               ...           ...                ...    ...
# 234  Yapıların Yalıtımı ve Korunması  Örgün Eğitim                  1      3
# 235                  Yapısal Jeoloji  Örgün Eğitim                  1      4
# 236  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      2
# 237  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      3
# 238                 Zemin Mekaniği 1  Örgün Eğitim                  1      4
#
#      LAB_SAAT  SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  \
# 0           0      4         2         1       S           4205238
# 1           1      4         2         0       S           4419464
# 2           0      2         2         1       S           1666337
# 3           0      3         4         0       Z           2576518
# 4           0      3         4         1       Z           7248701
# ..        ...    ...       ...       ...     ...               ...
# 234         0      4         2         1       S           1021641
# 235         0      2         3         1       Z           2446060
# 236         0      4         2         0       S           2832797
# 237         0      4         3         0       S           3473810
# 238         0      3         3         1       Z           2977082
#
#      OgrenciSayisi
# 0                6
# 1                9
# 2               15
# 3              105
# 4              116
# ..             ...
# 234             23
# 235             13
# 236             14
# 237             81
# 238            125
#
# [233 rows x 13 columns]

# %%
diff2 = df2[~df2['CourseCode'].isin(df['CourseCode'])]
diff2
# Out:
#               DepartmentName CourseCode  \
# 0         Çevre Mühendisliği    ÇEV 102
# 1         Çevre Mühendisliği    ÇEV 108
# 2         Çevre Mühendisliği    ÇEV 156
# 3         Çevre Mühendisliği    ÇEV 160
# 4         Çevre Mühendisliği    ÇEV 162
# ..                       ...        ...
# 221     Jeoloji Mühendisliği    MAT 162
# 222        Gıda Mühendisliği    MAT 162
# 223      Makine Mühendisliği    MAT 162
# 224  Bilgisayar Mühendisliği    MAT 222
# 225      Makine Mühendisliği    MTH 404
#
#                                   CourseName  SINIF ZOR_SEC  InstructorUserId  \
# 0                            Çevre Ekolojisi      1       Z           3979315
# 1                        Statik ve Mukavemet      1       S           1098471
# 2                       Computer Programming      1       Z           1307360
# 3                       Analytical Chemistry      1       S           2719999
# 4                                 Physics II      1       S           1830239
# ..                                       ...    ...     ...               ...
# 221                              Matematik 2      1       Z           2550816
# 222                             Matematik II      1       Z           4117613
# 223                             Matematik II      1       Z           1739868
# 224                           Linear Algebra      2       Z           4693090
# 225  Havacılık Yapısalları İmalat Teknikleri      4       S           1210302
#
#      OgrenciSayisi  Lab
# 0               19    0
# 1               19    0
# 2               18    1
# 3               22    0
# 4               18    0
# ..             ...  ...
# 221             15    0
# 222             99    0
# 223            159    0
# 224            135    0
# 225             34    0
#
# [220 rows x 8 columns]

# %%
df = df.drop(index=diff.index).reset_index(drop=True)
df
# Out:
#                      DepartmentName CourseCode            CourseName  \
# 0               İnşaat Mühendisliği    İNM 304         Çelik Yapılar
# 1                 Gıda Mühendisliği    FİZ 168              Fizik II
# 2  Elektrik-Elektronik Mühendisliği    EEM 350      Otomatik Kontrol
# 3  Elektrik-Elektronik Mühendisliği    EEM 304     Power Electronics
# 4           Bilgisayar Mühendisliği    CSE 332  Software Engineering
# 5                Çevre Mühendisliği    ÇEV 210          Termodinamik
#
#   EducationType  CourseSectionCode  KREDI  LAB_SAAT  SINIF  TEO_SAAT  \
# 0  Örgün Eğitim                  1      4         0      3         3
# 1  Örgün Eğitim                  1      3         0      1         2
# 2  Örgün Eğitim                  1      4         0      3         4
# 3     2.Öğretim                  1      3         0      3         3
# 4  Örgün Eğitim                  1      4         0      3         3
# 5  Örgün Eğitim                  1      3         0      2         3
#
#    UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi
# 0         1       Z           1318658              1
# 1         2       Z           3496303              1
# 2         0       Z           4721220              1
# 3         0       S           1029126              2
# 4         2       Z           1267061              1
# 5         0       S           4205238              1

# %%
df["Lab"] = 0
lab_codes = df2.loc[df2["Lab"] == 1, "CourseCode"]
df.loc[df["CourseCode"].isin(lab_codes), "Lab"] = 1
df
# Out:
#               DepartmentName CourseCode                        CourseName  \
# 0        İnşaat Mühendisliği    İNM 206               Akışkanlar Mekaniği
# 1        İnşaat Mühendisliği    İNM 302                       Betonarme 2
# 2        İnşaat Mühendisliği    İNM 352  Bilgisayar Destekli Yapı Analizi
# 3        İnşaat Mühendisliği    İNM 104            Bilgisayar Programlama
# 4        İnşaat Mühendisliği    İNM 304                     Çelik Yapılar
# ..                       ...        ...                               ...
# 226  Bilgisayar Mühendisliği    CSE 434             Programming Languages
# 227  Bilgisayar Mühendisliği    CSE 408            Scientific Programming
# 228  Bilgisayar Mühendisliği    CSE 392                           Seminar
# 229  Bilgisayar Mühendisliği    CSE 474           Social Network Analysis
# 230  Bilgisayar Mühendisliği    CSE 332              Software Engineering
#
#     EducationType  CourseSectionCode  KREDI  LAB_SAAT  SINIF  TEO_SAAT  \
# 0    Örgün Eğitim                  1      3         0      2         2
# 1    Örgün Eğitim                  1      4         0      3         3
# 2    Örgün Eğitim                  1      3         0      3         2
# 3    Örgün Eğitim                  1      3         0      1         2
# 4    Örgün Eğitim                  1      4         0      3         3
# ..            ...                ...    ...       ...    ...       ...
# 226  Örgün Eğitim                  1      4         0      4         3
# 227  Örgün Eğitim                  1      4         0      4         3
# 228  Örgün Eğitim                  1      1         0      3         0
# 229  Örgün Eğitim                  1      4         0      4         3
# 230  Örgün Eğitim                  1      4         0      3         3
#
#      UYG_SAAT ZOR_SEC  InstructorUserId  OgrenciSayisi  Lab
# 0           1       Z           3048102            125    0
# 1           1       Z           2669297            105    0
# 2           1       S           2669297             69    1
# 3           1       Z           1684669             74    1
# 4           1       Z           1318658             97    0
# ..        ...     ...               ...            ...  ...
# 226         1       S           2903204             51    0
# 227         1       S           7248701             44    1
# 228         2       Z           3143825             84    1
# 229         1       S           3435711             42    0
# 230         2       Z           1267061            102    1
#
# [231 rows x 14 columns]

# %%
df
# Out:
#                        DepartmentName CourseCode  \
# 0                  Çevre Mühendisliği    ÇEV 457
# 1                  Çevre Mühendisliği    ÇEV 461
# 2                  Çevre Mühendisliği    ÇEV 207
# 3                 Makine Mühendisliği    MAK 307
# 4             Bilgisayar Mühendisliği    CSE 301
# ..                                ...        ...
# 234               İnşaat Mühendisliği    İNM 467
# 235              Jeoloji Mühendisliği    JEO 209
# 236               Makine Mühendisliği    MAK 471
# 237  Elektrik-Elektronik Mühendisliği    EEE 499
# 238               İnşaat Mühendisliği    İNM 301
#
#                           CourseName EducationType  CourseSectionCode  KREDI  \
# 0              Air Pollution Control  Örgün Eğitim                  1      3
# 1            Air Pollution Modelling  Örgün Eğitim                  1      3
# 2                Akışkanlar Mekaniği  Örgün Eğitim                  1      3
# 3                Akışkanlar Mekaniği  Örgün Eğitim                  1      4
# 4                         Algorithms  Örgün Eğitim                  1      5
# ..                               ...           ...                ...    ...
# 234  Yapıların Yalıtımı ve Korunması  Örgün Eğitim                  1      3
# 235                  Yapısal Jeoloji  Örgün Eğitim                  1      4
# 236  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      2
# 237  Yenilenebilir Enerji Kaynakları  Örgün Eğitim                  1      3
# 238                 Zemin Mekaniği 1  Örgün Eğitim                  1      4
#
#      LAB_SAAT  SINIF  TEO_SAAT  UYG_SAAT ZOR_SEC  InstructorUserId  \
# 0           0      4         2         1       S           4205238
# 1           1      4         2         0       S           4419464
# 2           0      2         2         1       S           1666337
# 3           0      3         4         0       Z           2576518
# 4           0      3         4         1       Z           7248701
# ..        ...    ...       ...       ...     ...               ...
# 234         0      4         2         1       S           1021641
# 235         0      2         3         1       Z           2446060
# 236         0      4         2         0       S           2832797
# 237         0      4         3         0       S           3473810
# 238         0      3         3         1       Z           2977082
#
#      OgrenciSayisi
# 0                6
# 1                9
# 2               15
# 3              105
# 4              116
# ..             ...
# 234             23
# 235             13
# 236             14
# 237             81
# 238            125
#
# [239 rows x 13 columns]

# %%
df.to_excel("./course_data3.xlsx", index=False, header=True)

# %% [markdown]
# Lab saatlerini uygulamaya yaz
